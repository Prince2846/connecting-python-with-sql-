# %%
import ibm_db

# %%
#Replace the placeholder values with the actuals for your Db2 Service Credentials
dsn_driver = "{IBM_Db2-y5}"
dsn_database = "BLUDB"                                                          # e.g. "BLUDB"
dsn_hostname = "dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net"         # e.g.: "dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net"
dsn_port = "50000"                                                              # e.g. "50000" 
dsn_protocol = "TCPIP"                                                          # i.e. "TCPIP"
dsn_uid = "knt55269"                                                            # e.g. "abc12345"
dsn_pwd = "v9ztv94mhf^3k247"                                                    # e.g. "7dBZ3wWt9XN6$o0J"

# %%
#Create database connection
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd)

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  BLUDB as user:  knt55269 on host:  dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net

# %%
selectquery = "select * from EMPLOYEE"

querystmt  = ibm_db.exec_immediate(conn, selectquery)

ibm_db.fetch_both(querystmt)
# Out:
# {'EMP_ID': 'E1002    ',
#  0: 'E1002    ',
#  'F_NAME': 'Alice',
#  1: 'Alice',
#  'L_NAME': 'James',
#  2: 'James',
#  'SSN': '123457   ',
#  3: '123457   '}

# %%
import pandas
import ibm_db_dbi

# %%
#connection for pandas
pconn = ibm_db_dbi.Connection(conn)

# %%
#query statement to retrieve all rows in INSTRUCTOR table
selectQuery = "select * from CHICAGO_CRIME_DATA"

#retrieve the query results into a pandas dataframe
pdf = pandas.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
pdf
# Out:
#            ID CASE_NUMBER                    DATE                     BLOCK  \
# 0     3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1     3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2     8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3     7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4    10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
# 5     7732712    HS540106  09/29/2010 07:59:00 AM       006XX W CHICAGO AVE
# 6    10769475    HZ534771  11/30/2016 01:15:00 AM        050XX N KEDZIE AVE
# 7     4494340    HL793243  12/16/2005 04:45:00 PM       005XX E PERSHING RD
# 8     3778925    HL149610  01/28/2005 05:00:00 PM     100XX S WASHTENAW AVE
# 9     3324217    HK361551  05/13/2004 02:15:00 PM       033XX W BELMONT AVE
# 10    9902691    HX552797  12/23/2014 02:15:00 PM        076XX S CICERO AVE
# ...

# %%
#query statement to retrieve all rows in INSTRUCTOR table
selectQuery = "select * from INSTRUCTOR"

#retrieve the query results into a pandas dataframe
pdf1 = pandas.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
pdf1
# Out:
#    ID   FNAME      LNAME     CITY                 CCODE
# 0   1     Rav      Ahuja  TORONTO  CA
# 1   2    Raul      Chong  Markham  CA
# 2   3    Hima  Vasudevan  Chicago  US
# 3   4  Prince    Muyumba  TORONTO  ZA

# %%
# retreiving the unique value in the column
pdf['ARREST'].unique()
# Out:
# array(['FALSE', 'TRUE'], dtype=object)

# %%
import numpy as np

# %%
selectQuery = "select * from CHICAGO_CRIME_DATA where ARREST = True"
#retrieve the query results into a pandas dataframe
pdf2 = pandas.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
pdf2
# Out:
#            ID CASE_NUMBER                    DATE                     BLOCK  \
# 0     4494340    HL793243  12/16/2005 04:45:00 PM       005XX E PERSHING RD
# 1     9902691    HX552797  12/23/2014 02:15:00 PM        076XX S CICERO AVE
# 2     6866556    HR271603  04/16/2009 05:30:00 PM  089XX S STONY ISLAND AVE
# 3    10046030    HY234744  04/24/2015 07:55:00 PM      008XX N MICHIGAN AVE
# 4    11230490    JB151690  02/14/2018 11:15:00 AM        036XX S ARCHER AVE
# 5     4718689    HM324025  05/01/2006 03:20:00 PM            0000X W ELM ST
# 6     6855661    HR261581  04/10/2009 05:00:00 PM         017XX W CERMAK RD
# 7    11143628    JA503725  11/08/2017 10:38:00 AM       058XX S ASHLAND AVE
# 8     5214424    HM803061  12/31/2006 11:53:00 AM       029XX N ASHLAND AVE
# 9     6980726    HR385117  06/20/2009 11:25:00 AM        076XX S CICERO AVE
# 10    2522757    HH869886  12/31/2002 03:15:00 PM         048XX W NORTH AVE
# ...

# %%
x = np.array(pdf2['ARREST'])
print(x.shape)
# Out:
# (142,)

# %%
selectQuery = "select PRIMARY_TYPE from CHICAGO_CRIME_DATA where LOCATION_DESCRIPTION LIKE 'GAS STATION'"
#retrieve the query results into a pandas dataframe
pdf3 = pandas.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
pdf3
# Out:
#         PRIMARY_TYPE
# 0              THEFT
# 1              THEFT
# 2          NARCOTICS
# 3            ROBBERY
# 4            ROBBERY
# 5  CRIMINAL TRESPASS

# %%
selectQuery = "select * from  CENUS_DATA table"
#retrieve the query results into a pandas dataframe
pdf4 = pandas.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
pdf4.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 0                                          18.2
# ...

# %%
selectQuery = "select COMMUNITY_AREA_NAME from CENUS_DATA table"
#retrieve the query results into a pandas dataframe
pdf4 = pandas.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
pdf4.head()
# Out:
#   COMMUNITY_AREA_NAME
# 0         Rogers Park
# 1          West Ridge
# 2              Uptown
# 3      Lincoln Square
# 4        North Center
